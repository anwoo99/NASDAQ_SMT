# %%
import pandas as pd
from datetime import datetime, timedelta
# Out:
# /tmp/ipykernel_171350/2883196732.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)
df = pd.read_csv(r"/mdfsvc/fep/log/Smart/OSMT_0x22-3.csv", lineterminator='\n', index_col='Date')

# %%
"""
타임스탬프 변환 파트
"""
df["Datetime"] = df["Seconds"].apply(lambda x: datetime.fromtimestamp(x))
df["Timestamp(Convert)"] = df["Datetime"].apply(lambda x: x.strftime('%H:%M:%S'))
df = df[['Time', 'Message Type', 'Protocol ID', 'Timestamp(Convert)', 'Channel Index', 'Seconds', 'Raw Data']]
df
# Out:
#            Time Message Type  Protocol ID Timestamp(Convert)  Channel Index  \
# Date
# 02/07  16:53:12         0x22           52           15:30:00             73
# 02/07  16:53:12         0x22           52           15:30:01             73
# 02/07  16:53:12         0x22           52           17:00:00             73
# 02/07  16:53:12         0x22           52           17:00:01             73
# 02/07  16:53:12         0x22           52           17:00:02             73
# ...         ...          ...          ...                ...            ...
# 02/07  21:09:45         0x22           51           18:25:06              5
# 02/07  21:09:45         0x22           51           18:25:08              5
# 02/07  21:09:45         0x22           51           18:30:00              5
# 02/07  21:09:45         0x22           51           18:30:01              5
# 02/07  21:09:45         0x22           51           18:30:02              5
#
#        Seconds               Raw Data
# Date
# 02/07    23400  22 34 49 00 00 5B 68
# 02/07    23401  22 34 49 00 00 5B 69
# 02/07    28800  22 34 49 00 00 70 80
# 02/07    28801  22 34 49 00 00 70 81
# 02/07    28802  22 34 49 00 00 70 82
# ...        ...                    ...
# 02/07    33906  22 33 05 00 00 84 72
# 02/07    33908  22 33 05 00 00 84 74
# 02/07    34200  22 33 05 00 00 85 98
# 02/07    34201  22 33 05 00 00 85 99
# 02/07    34202  22 33 05 00 00 85 9A
#
# [2489 rows x 7 columns]
