# %%
import pandas as pd
import dask.dataframe as dd
from datetime import datetime, timedelta
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_171768/3353734925.py:4: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
"""
호가는 파일이 너무 큰 관계로, 크기를 잘라서 확인
"""
chunk_size = 1000000
df = pd.read_csv('/mdfsvc/fep/log/Smart/OSMT_NBBO-3.csv', nrows=chunk_size)

# %%
"""
Two Sided NBBO Update - Short Form(0x60)
"""
df[(df["Message Type"] == "0x60")].head(2)
# Out:
#     Date      Time Message Type  Protocol ID  Channel Index Message Flags  \
# 0  02/07  16:53:12         0x60           52             73          0x00
# 1  02/07  16:53:12         0x60           52             73          0x00
#
#    Upstream Sequence Number  Upstream Nanos  Instrument Locate  \
# 0                     16442        55814400              13858
# 1                     16443        55814400              13210
#
#    Bid Market Center Locate  Bid Denominator  Bid Price  Bid Size  \
# 0                         0                2        0.0         0
# 1                         0                2        0.0         0
#
#    Ask Market Center Locate  Ask Denominator  Ask Price  Ask Size  \
# 0                         0                2        0.0         0
# 1                         0                2        0.0         0
#
#   RFU/Condition Flags                                           Raw Data
# ...

# %%
"""
Two Sided NBBO Update - Long Form(0x61)
"""
df[(df["Message Type"] == "0x61") & (df["Instrument Locate"] == 11356)].tail(100)
# Out:
#          Date      Time Message Type  Protocol ID  Channel Index  \
# 119662  02/07  20:01:49         0x61           51              5
# 121658  02/07  20:01:49         0x61           51              5
# 123793  02/07  20:01:49         0x61           51              5
# 127065  02/07  20:01:49         0x61           51              5
# 129484  02/07  20:01:49         0x61           51              5
# 184324  02/07  20:01:50         0x61           51              5
# 230628  02/07  20:01:51         0x61           51              5
# 447182  02/07  20:01:56         0x61           51              5
# 448690  02/07  20:01:56         0x61           51              5
# 515895  02/07  20:01:57         0x61           51              5
# 641220  02/07  20:02:00         0x61           51              5
# 660779  02/07  20:02:01         0x61           51              5
# 680054  02/07  20:02:01         0x61           51              5
# ...

# %%
"""
Two Sided NBBO Update - Extended Form(0x62)
"""
df[(df["Message Type"] == "0x62")].head(2)
# Out:
# Empty DataFrame
# Columns: [Date, Time, Message Type, Protocol ID, Channel Index, Message Flags, Upstream Sequence Number, Upstream Nanos, Instrument Locate, Bid Market Center Locate, Bid Denominator, Bid Price, Bid Size, Ask Market Center Locate, Ask Denominator, Ask Price, Ask Size, RFU/Condition, Flags, Raw Data]
# Index: []

# %%
"""
One Sided NBBO Update-Short Fromat(0x63)
"""

df[df["Message Type"] == "0x63"].head(2)
# Out:
#         Date      Time Message Type  Protocol ID  Channel Index Message Flags  \
# 20359  02/07  16:53:15         0x63           52             73          0x00
# 20434  02/07  16:53:15         0x63           52             73          0x00
#
#        Upstream Sequence Number  Upstream Nanos  Instrument Locate  \
# 20359                     37367        35888384              13049
# 20434                     37449        42484224              13554
#
#        Bid Market Center Locate  Bid Denominator  Bid Price  Bid Size  \
# 20359                         0                0        0.0         0
# 20434                         7                2        1.1       339
#
#        Ask Market Center Locate  Ask Denominator  Ask Price  Ask Size  \
# 20359                        12                2       0.55       239
# 20434                         0                0       0.00         0
#
#       RFU/Condition Flags                                           Raw Data
# ...

# %%
"""
One Sided NBBO Update-Long Fromat(0x64)
"""

df[df["Message Type"] == "0x64"].head(2)
# Out:
#          Date      Time Message Type  Protocol ID  Channel Index  \
# 121209  02/07  20:01:49         0x64           51              5
# 121713  02/07  20:01:49         0x64           51              5
#
#        Message Flags  Upstream Sequence Number  Upstream Nanos  \
# 121209          0x00                     34102        83145519
# 121713          0x00                     34655       106231558
#
#         Instrument Locate  Bid Market Center Locate  Bid Denominator  \
# 121209              10382                         4                4
# 121713              10294                         0                0
#
#         Bid Price  Bid Size  Ask Market Center Locate  Ask Denominator  \
# 121209      474.0         1                         0                0
# 121713        0.0         0                         4                4
#
#         Ask Price  Ask Size RFU/Condition Flags  \
# 121209        0.0         0          0x00  0x00
# ...

# %%
"""
One Sided NBBO Update-Extended Fromat(0x65)
"""

df[df["Message Type"] == "0x65"].head(2)
# Out:
# Empty DataFrame
# Columns: [Date, Time, Message Type, Protocol ID, Channel Index, Message Flags, Upstream Sequence Number, Upstream Nanos, Instrument Locate, Bid Market Center Locate, Bid Denominator, Bid Price, Bid Size, Ask Market Center Locate, Ask Denominator, Ask Price, Ask Size, RFU/Condition, Flags, Raw Data]
# Index: []
