# %%
import pandas as pd
import dask.dataframe as dd
from datetime import datetime, timedelta
from IPython.core.display import display, HTML
# Out:
# /tmp/ipykernel_509978/2280673788.py:4: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
df = pd.read_csv('/mdfsvc/fep/log/Smart/OSMT_TRADE-4.csv')
df[df["Price Flags"] == "0x80"]
# Out:
# Empty DataFrame
# Columns: [Date, Time, Message Type, Protocol ID, Channel Index, Message Flags, Upstream Sequence Number, Upstream Nanos, Instrument Locate, Market Center Locate, Trade ID, Price Denominator, Price, Size, Price Flags, Eligibility Flags, Report Flags, Change Flags, Cancel Flags, Upstream Condition Detail, Trade Report Detail, Extended Report Flag, Raw Data]
# Index: []

# %%
"""
Short Trade Message Type(0x70)
"""
#df[(df["Message Type"] == "0x70")].tail(5).iloc[:, :10]
df[(df["Trade ID"] == 381) & (df["Instrument Locate"] == 13730)]
# Out:
#        Date      Time Message Type  Protocol ID  Channel Index Message Flags  Upstream Sequence Number  Upstream Nanos  Instrument Locate  Market Center Locate  Trade ID  Price Denominator  Price  Size Price Flags Eligibility Flags Report Flags Change Flags Cancel Flags  Upstream Condition Detail  Trade Report Detail Extended Report Flag                                           Raw Data
# 1186  02/15  21:30:59         0x70           52             73          0x00                  24482932       261414656              13730                524288       381                  2   0.15   248        0x00              0x00       0x0A01         0x0F         0x00                        NaN                    0           0x00000000  70 34 49 00 01 75 94 74 0F 94 DF 00 00 00 35 A...
# ...

# %%
df[(df["Message Type"] == "0x70")].tail(5).iloc[:, 10:]
# Out:
#         Trade ID  Price Denominator  Price  Size Price Flags Eligibility Flags Report Flags Change Flags Cancel Flags  Upstream Condition Detail  Trade Report Detail Extended Report Flag                                           Raw Data
# 130531        45                  2   0.01   248        0x00              0x00       0x0A01         0x0F         0x00                        NaN                    0           0x00000000  70 34 4B 00 0B D5 34 C7 34 CE DA 00 00 00 36 6...
# 130532        84                  2   0.02   248        0x00              0x00       0x0A01         0x0F         0x00                        NaN                    0           0x00000000  70 34 4B 00 0B D5 42 E0 37 F4 26 00 00 00 34 1...
# 130533       119                  2   0.04   248        0x00              0x20       0x0A01         0x0F         0x00                        NaN                    0           0x00000000  70 34 4B 00 0B D5 6E 8F 09 CC 2D 00 00 00 36 5...
# ...

# %%
"""
Long Trade Message Type(0x71)
"""
df[(df["Message Type"] == "0x71")].head(5).iloc[:, :10]
# Out:
# Empty DataFrame
# Columns: [Date, Time, Message Type, Protocol ID, Channel Index, Message Flags, Upstream Sequence Number, Upstream Nanos, Instrument Locate, Market Center Locate]
# Index: []

# %%
df[(df["Message Type"] == "0x71")].head(5).iloc[:, 10:]
# Out:
# Empty DataFrame
# Columns: [Trade ID, Price Denominator, Price, Size, Price Flags, Eligibility Flags, Report Flags, Change Flags, Cancel Flags, Upstream Condition Detail, Trade Report Detail, Extended Report Flag, Raw Data]
# Index: []

# %%
"""
Extended Trade Message Type(0x72)
"""
df[(df["Message Type"] == "0x72")].head(5).iloc[:, :10]
# Out:
# Empty DataFrame
# Columns: [Date, Time, Message Type, Protocol ID, Channel Index, Message Flags, Upstream Sequence Number, Upstream Nanos, Instrument Locate, Market Center Locate]
# Index: []

# %%
df[(df["Message Type"] == "0x72")].head(5).iloc[:, 10:]
# Out:
# Empty DataFrame
# Columns: [Trade ID, Price Denominator, Price, Size, Price Flags, Eligibility Flags, Report Flags, Change Flags, Cancel Flags, Upstream Condition Detail, Trade Report Detail, Extended Report Flag, Raw Data]
# Index: []

# %%
"""
Trade Cancel Message Type(0x73)
"""
df[(df["Message Type"] == "0x73")].head(5).iloc[:, :10]
# Out:
# Empty DataFrame
# Columns: [Date, Time, Message Type, Protocol ID, Channel Index, Message Flags, Upstream Sequence Number, Upstream Nanos, Instrument Locate, Market Center Locate]
# Index: []

# %%
df[(df["Message Type"] == "0x73")].head(5).iloc[:, 10:]
# Out:
# Empty DataFrame
# Columns: [Trade ID, Price Denominator, Price, Size, Price Flags, Eligibility Flags, Report Flags, Change Flags, Cancel Flags, Upstream Condition Detail, Trade Report Detail, Extended Report Flag, Raw Data]
# Index: []
