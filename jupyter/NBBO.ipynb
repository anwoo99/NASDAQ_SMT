# %%
import pandas as pd
import dask.dataframe as dd
from datetime import datetime, timedelta
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_17696\3353734925.py:4: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
"""
호가는 파일이 너무 큰 관계로, 크기를 잘라서 확인
"""
chunk_size = 1000000
df = pd.read_csv('../NasdaqSMT_Csv/OSMT_NBBO-4.csv', nrows=chunk_size)

# %%
"""
Two Sided NBBO Update - Short Form(0x60)
"""
df[(df["Message Type"] == "0x60")].head(2)
# Out:
#     Date      Time Message Type  Protocol ID  Channel Index Message Flags  \
# 0  02/01  13:19:14         0x60           51              5          0x00
# 1  02/01  13:19:14         0x60           51              5          0x00
#
#    Upstream Sequence Number  Upstream Nanos  Instrument Locate  \
# 0                     10253        45433318               9654
# 1                     10253        45433318               9655
#
#    Bid Market Center Locate  Bid Denominator  Bid Price  Bid Size  \
# 0                         0                2        0.0         0
# 1                         0                2        0.0         0
#
#    Ask Market Center Locate  Ask Denominator  Ask Price  Ask Size  \
# 0                         0                2        0.0         0
# 1                         0                2        0.0         0
#
#   RFU/Condition Flags                                           Raw Data
# 0          0x00  0x00  60 33 05 00 00 00 28 0D 02 B5 41 E6 00 00 25 B...
# 1          0x00  0x00  60 33 05 00 00 00 28 0D 02 B5 41 E6 00 00 25 B...

# %%
"""
Two Sided NBBO Update - Long Form(0x61)
"""
df[(df["Message Type"] == "0x61")].head(2)
# Out:
#         Date      Time Message Type  Protocol ID  Channel Index Message Flags  \
# 32961  02/01  13:19:16         0x61           51              5          0x00
# 32962  02/01  13:19:16         0x61           51              5          0x00
#
#        Upstream Sequence Number  Upstream Nanos  Instrument Locate  \
# 32961                     32847         2011307              10362
# 32962                     32848         2019096              11341
#
#        Bid Market Center Locate  Bid Denominator  Bid Price  Bid Size  \
# 32961                         3                4    2058.00         1
# 32962                         3                4    1771.25         1
#
#        Ask Market Center Locate  Ask Denominator  Ask Price  Ask Size  \
# 32961                         3                4    2082.00         1
# 32962                         3                4    1795.25         1
#
#       RFU/Condition Flags                                           Raw Data
# 32961          0x00  0x00  61 33 05 00 00 00 80 4F 00 1E B0 AB 00 00 28 7...
# 32962          0x00  0x00  61 33 05 00 00 00 80 50 00 1E CF 18 00 00 2C 4...

# %%
"""
Two Sided NBBO Update - Extended Form(0x62)
"""
df[(df["Message Type"] == "0x62")].head(2)
# Out:
# Empty DataFrame
# Columns: [Date, Time, Message Type, Protocol ID, Channel Index, Message Flags, Upstream Sequence Number, Upstream Nanos, Instrument Locate, Bid Market Center Locate, Bid Denominator, Bid Price, Bid Size, Ask Market Center Locate, Ask Denominator, Ask Price, Ask Size, RFU/Condition, Flags, Raw Data]
# Index: []

# %%
"""
One Sided NBBO Update-Short Fromat(0x63)
"""

df[df["Message Type"] == "0x63"].head(2)
# Out:
#         Date      Time Message Type  Protocol ID  Channel Index Message Flags  \
# 32967  02/01  13:19:16         0x63           51              5          0x00
# 32968  02/01  13:19:16         0x63           51              5          0x00
#
#        Upstream Sequence Number  Upstream Nanos  Instrument Locate  \
# 32967                     32854         2331481              10679
# 32968                     32855         2339057              11146
#
#        Bid Market Center Locate  Bid Denominator  Bid Price  Bid Size  \
# 32967                         0                0        0.0         0
# 32968                         0                0        0.0         0
#
#        Ask Market Center Locate  Ask Denominator  Ask Price  Ask Size  \
# 32967                         2                2     261.15         1
# 32968                         2                2     254.90         1
#
#       RFU/Condition Flags                                           Raw Data
# 32967          0x00  0x00  63 33 05 00 00 00 80 56 00 23 93 59 00 00 29 B...
# 32968          0x00  0x00  63 33 05 00 00 00 80 57 00 23 B0 F1 00 00 2B 8...

# %%
"""
One Sided NBBO Update-Long Fromat(0x64)
"""

df[df["Message Type"] == "0x64"].head(2)
# Out:
#         Date      Time Message Type  Protocol ID  Channel Index Message Flags  \
# 34644  02/01  13:19:16         0x64           51              5          0x00
# 35148  02/01  13:19:16         0x64           51              5          0x00
#
#        Upstream Sequence Number  Upstream Nanos  Instrument Locate  \
# 34644                     34102        83145519              10382
# 35148                     34655       106231558              10294
#
#        Bid Market Center Locate  Bid Denominator  Bid Price  Bid Size  \
# 34644                         4                4      474.0         1
# 35148                         0                0        0.0         0
#
#        Ask Market Center Locate  Ask Denominator  Ask Price  Ask Size  \
# 34644                         0                0        0.0         0
# 35148                         4                4      680.0         1
#
#       RFU/Condition Flags                                           Raw Data
# 34644          0x00  0x00  64 33 05 00 00 00 85 36 04 F4 B3 2F 00 00 28 8...
# 35148          0x00  0x00  64 33 05 00 00 00 87 5F 06 54 F7 06 00 00 28 3...

# %%
"""
One Sided NBBO Update-Extended Fromat(0x65)
"""

df[df["Message Type"] == "0x65"].head(2)
# Out:
# Empty DataFrame
# Columns: [Date, Time, Message Type, Protocol ID, Channel Index, Message Flags, Upstream Sequence Number, Upstream Nanos, Instrument Locate, Bid Market Center Locate, Bid Denominator, Bid Price, Bid Size, Ask Market Center Locate, Ask Denominator, Ask Price, Ask Size, RFU/Condition, Flags, Raw Data]
# Index: []
